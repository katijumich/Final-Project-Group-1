# %% [markdown]
# Group 1 Final Project Parallel Categories Code by Kati Johnson

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.graph_objs.layout import title

# %%
df = pd.read_csv('/content/drive/MyDrive/CSC302 Group Project/HR-Employee-Attrition.csv')
#df.head()
#df.dtypes

# %%
# create a list of our conditions
conditions = [
    (df['HourlyRate'] <= 48),
    (df['HourlyRate'] >= 49) & (df['HourlyRate'] <= 66),
    (df['HourlyRate'] >= 67) & (df['HourlyRate'] <= 84),
    (df['HourlyRate'] >= 85)
    ]

# create a list of the values we want to assign for each condition
values = ['tier_1', 'tier_2', 'tier_3', 'tier_4']

# create a new column and use np.select to assign values to it using our lists as arguments
df['HourlyPayTier'] = np.select(conditions, values)
#df=df[df.HourlyPayTier.notnull()]

# display updated DataFrame
df.to_csv('/content/drive/MyDrive/testoutput.csv')

# %%
job_satis = go.parcats.Dimension(
    values=df.JobSatisfaction,
    categoryarray=[1, 2, 3, 4], label="Job Satisfaction",
     ticktext=['Low', 'Medium', 'High', 'Very High'])

wl_balance = go.parcats.Dimension(
    values=df.WorkLifeBalance,
   categoryarray=[1, 2, 3, 4], label="Work Life Balance",  ticktext=['Bad','Good','Better','Best'])

hourly_pay = go.parcats.Dimension(
    values=df.HourlyPayTier,
     categoryarray=['tier_1', 'tier_2', 'tier_3', 'tier_4'], 
     label="Hourly Pay Tier",
    ticktext=['&#36;30-&#36;48', "&#36;49-&#36;66", "&#36;67-&#36;84", "&#36;85-&#36;100"])
                                                           
color = df.JobSatisfaction;
colorscale =('geyser');

fig = go.Figure(data = [go.Parcats(dimensions=[job_satis, wl_balance, hourly_pay],
        line={'color': color, 'colorscale': colorscale},
        hoveron='color', hoverinfo='count+probability',
        labelfont={'size': 20, 'family': 'Arial Black'},
        tickfont={'size': 18, 'family': 'Arial Black'},
        arrangement='fixed')]
    )
fig.update_layout(title_text='Employee Job Satisfaction Compared to Work Life Balance and Pay',
                    title_font_family="Arial Black",
               title_font_size=30)
                
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8833f656-a6e2-42d2-95d0-1f3fd73f22c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8833f656-a6e2-42d2-95d0-1f3fd73f22c9")) {                    Plotly.newPlot(                        "8833f656-a6e2-42d2-95d0-1f3fd73f22c9",                        [{"arrangement":"fixed","dimensions":[{"categoryarray":[1,2,3,4],"label":"Job Satisfaction","ticktext":["Low","Medium","High","Very High"],"values":[4,2,3,3,2,4,1,3,3,3,2,3,3,4,3,1,2,4,4,4,3,1,2,4,1,3,1,2,4,1,4,4,3,4,4,3,3,4,1,1,4,1,3,3,4,3,3,2,4,4,3,3,1,1,4,4,1,1,4,3,4,4,3,1,3,3,2,1,1,3,3,2,2,2,4,4,1,1,3,2,4,3,4,4,2,4,1,4,4,4,2,4,2,1,3,3,3,3,3,2,1,1,4,3,4,4,2,3,4,4,1,3,4,3,2,4,1,4,4,4,3,2,2,3,3,2,4,3,4,1,3,4,3,3,3,2,4,3,3,4,1,4,3,3,4,1,4,1,1,2,2,2,3,2,4,3,